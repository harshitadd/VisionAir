# %% [markdown]
# <a href="https://colab.research.google.com/github/harshitadd/Celestini/blob/master/weatherscraper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install firebase-admin 
import firebase_admin
from firebase_admin import storage, credentials,db
import pandas as pd

# %%
cred = credentials.Certificate('credentials.json')

# Initialize the app with a service account, granting admin privileges
firebase_admin.initialize_app(cred, {
    'databaseURL': 'https://fir-4ca2c.firebaseio.com/'
})

# %%
    
ref = db.reference()
df = ref.get()

# %%
temp_weather = {}

for key in df:
  try:
    l=[]
    l.append(df[key]['main']['humidity'])
    l.append(df[key]['main']['pressure'])
    l.append(df[key]['main']['temp'])
    l.append(df[key]['visibility'])
    l.append(df[key]['wind']['deg'])
    l.append(df[key]['wind']['speed'])
    temp_weather[key]=l
  except:
    print(key)
# Out:
# 08-07-2019 02:52:50
# 08-07-2019 02:57:50

# %%
print(len(temp_weather))
# Out:
# 5805

# %%
print(temp_weather)
# Out:
# {'01-07-2019 05:31:16': [52, 999, 35.13, 3500, 250, 2.1], '01-07-2019 05:36:16': [52, 999, 35.55, 3500, 260, 2.6], '01-07-2019 05:41:16': [52, 999, 35.55, 3500, 260, 2.6], '01-07-2019 05:46:16': [52, 999, 35.55, 3500, 260, 2.6], '01-07-2019 05:51:16': [52, 999, 34.16, 3500, 260, 2.6], '01-07-2019 05:56:16': [52, 999, 34.16, 3500, 260, 2.6], '01-07-2019 06:01:16': [52, 999, 34.16, 3500, 260, 2.6], '01-07-2019 06:06:16': [52, 999, 34.59, 3500, 270, 1.5], '01-07-2019 06:11:16': [52, 999, 34.6, 3500, 270, 1.5], '01-07-2019 06:16:16': [52, 999, 34.59, 3500, 270, 1.5], '01-07-2019 06:21:16': [52, 999, 34.61, 3500, 270, 1.5], '01-07-2019 06:26:16': [52, 999, 34.61, 3500, 270, 1.5], '01-07-2019 06:31:16': [55, 1000, 34.27, 3500, 250, 1.5], '01-07-2019 06:36:16': [55, 1000, 34.27, 3500, 250, 1.5], '01-07-2019 06:41:16': [55, 1000, 34.27, 3500, 250, 1.5], '01-07-2019 06:46:16': [55, 1000, 34.3, 3500, 250, 1.5], '01-07-2019 06:51:16': [55, 1000, 34.31, 3500, 250, 1.5], '01-07-2019 06:56:16': [55, 1000, 34.55, 4000, 270, 2.6], '01-07-2019 07:01:16': [55, 1000, 34.55, 4000, 270, 2.6], '01-07-2019 07:06:16': [55, 1000, 34.55, 4000, 270, 2.6], '01-07-2019 07:11:16': [55, 1000, 34.29, 4000, 270, 2.6], '01-07-2019 07:16:16': [55, 1000, 34.3, 4000, 270, 2.6], '01-07-2019 07:21:16': [55, 1000, 34.3, 4000, 270, 2.6], '01-07-2019 07:26:16': [55, 1000, 34.55, 4000, 260, 2.6], '01-07-2019 07:31:16': [55, 1000, 34.3, 4000, 270, 2.6], '01-07-2019 07:36:16': [55, 1000, 34.55, 4000, 260, 2.6], '01-07-2019 07:41:16': [55, 1000, 33.98, 4000, 260, 2.6], '01-07-2019 07:46:16': [55, 1000, 34.45, 4000, 260, 2.6], '01-07-2019 07:51:16': [55, 1000, 34.45, 4000, 260, 2.6], '01-07-2019 07:56:16': [52, 1000, 34.04, 3500, 220, 2.1], '01-07-2019 08:01:16': [52, 1000, 34.04, 3500, 220, 2.1], '01-07-2019 08:06:16': [52, 1000, 34.05, 3500, 220, 2.1], '01-07-2019 08:11:16': [52, 1000, 34.06, 3500, 220, 2.1], '01-07-2019 08:16:16': [52, 1000, 34.06, 3500, 220, 2.1], '01-07-2019 08:21:16': [52, 1000, 34.06, 3500, 220, 2.1], '01-07-2019 08:26:16': [52, 1000, 33.75, 3500, 220, 2.1], '01-07-2019 08:31:16': [55, 1000, 34.16, 3500, 220, 1.5], '01-07-2019 08:36:16': [55, 1000, 34.16, 3500, 220, 1.5], '01-07-2019 08:41:16': [55, 1000, 34.16, 3500, 220, 1.5], '01-07-2019 08:46:16': [55, 1000, 34.17, 3500, 220, 1.5], '01-07-2019 08:51:16': [55, 1000, 34.17, 3500, 220, 1.5], '01-07-2019 08:56:16': [55, 1000, 34.17, 3500, 220, 1.5], '01-07-2019 09:01:16': [52, 1000, 34.56, 3500, 200, 1], '01-07-2019 09:06:16': [52, 1000, 34.56, 3500, 200, 1], '01-07-2019 09:11:16': [52, 1000, 34.56, 3500, 200, 1], '01-07-2019 09:16:16': [52, 1000, 34.54, 3500, 200, 1], '01-07-2019 09:21:16': [52, 1000, 34.54, 3500, 200, 1], '01-07-2019 09:26:16': [56, 1000, 34.9, 3500, 50, 1], '01-07-2019 09:31:16': [56, 1000, 34.9, 3500, 50, 1], '01-07-2019 09:36:16': [56, 1000, 34.9, 3500, 50, 1], '01-07-2019 09:41:16': [56, 1000, 34.9, 3500, 50, 1], '01-07-2019 09:46:16': [56, 1000, 34.9, 3500, 50, 1], '01-07-2019 09:51:16': [56, 1000, 34.91, 3500, 50, 1], '01-07-2019 09:56:16': [56, 1000, 34.91, 3500, 50, 1], '01-07-2019 10:01:16': [56, 1000, 35.51, 3500, 230, 2.6], '01-07-2019 10:06:16': [56, 1000, 35.51, 3500, 230, 2.6], '01-07-2019 10:11:16': [56, 1000, 35.51, 3500, 230, 2.6], '01-07-2019 10:16:16': [56, 1000, 35.51, 3500, 230, 2.6], '01-07-2019 10:21:16': [56, 1000, 35.51, 3500, 230, 2.6], '01-07-2019 10:26:16': [56, 1000, 35.51, 3500, 230, 2.6], '01-07-2019 10:31:16': [53, 1000, 36.51, 3500, 250, 1.5], '01-07-2019 10:36:16': [53, 1000, 36.51, 3500, 250, 1.5], '01-07-2019 10:41:16': [53, 1000, 36.51, 3500, 250, 1.5], '01-07-2019 10:46:16': [53, 1000, 36.51, 3500, 250, 1.5], '01-07-2019 10:51:16': [53, 1000, 36.51, 3500, 250, 1.5], '01-07-2019 10:56:16': [53, 1000, 36.51, 3500, 250, 1.5], '01-07-2019 11:01:16': [53, 1000, 36.51, 3500, 250, 1.5], '01-07-2019 11:06:16': [47, 1000, 37.51, 3500, 50, 1], '01-07-2019 11:11:16': [47, 1000, 37.51, 3500, 50, 1], '01-07-2019 11:16:16': [47, 1000, 37.51, 3500, 50, 1], ' ...

# %%
weather={}
for key in temp_weather:
  temp=key.split('-')
  newtemp=temp[2].split(' ')
  newesttemp=newtemp[1].split(':')
  j=int(newesttemp[1])
  if(j<=7.5):
    final = newtemp[0] + '-' + temp[1] + '-' + temp[0] + ' ' + newesttemp[0] + ':' + '00'
  elif(j<=15 or j<=22.5):
    final = newtemp[0] + '-' + temp[1] + '-' + temp[0] + ' ' + newesttemp[0] + ':' + '15'
  elif(j<=30 or j<=37.5):
    final = newtemp[0] + '-' + temp[1] + '-' + temp[0] + ' ' + newesttemp[0] + ':' + '30'
  elif(j<=45 or j<=52.5):
    final = newtemp[0] + '-' + temp[1] + '-' + temp[0] + ' ' + newesttemp[0] + ':' + '45'
  elif(j>52.5):
    final = newtemp[0] + '-' + temp[1] + '-' + temp[0] + ' ' + newesttemp[0] + ':' + '00'
  if(final not in weather):
    weather[final]=temp_weather[key]

# %%
print(len(weather))
# Out:
# 1939
